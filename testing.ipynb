# %% [markdown]
# Declarations

# %%
from dataclasses import dataclass, field
from openai import OpenAI
from dotenv import dotenv_values
from pprint import pprint
from functools import wraps
import requests
import base64

from ai_client_wrapper import AI_Client_Call_Wrapper


env = dotenv_values(".env")
ac3 = AI_Client_Call_Wrapper.make_from_key(api_key=env["OPENAI_API_KEY"])
ac = AI_Client_Call_Wrapper(api_key=env["OPENAI_API_KEY"])
ac2 = AI_Client_Call_Wrapper.make_from_key(api_key=env["OPENAI_API_KEY"])

for f in env:
    pprint(f)
# Out:
# 'OPENAI_API_KEY'

# %% [markdown]
# Testing

# %%
r, i = ac2.call_text_embeddings('Dlaczego ostryga nazywa sie ostrygą')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 r, i = ac2.call_text_embeddings('Dlaczego ostryga nazywa sie ostrygą')
#
# NameError: name 'ac2' is not defined

# %%
from qdrant_client import QdrantClient
qdrant = QdrantClient("http://localhost:6333")

# %%
r = requests.get('http://google.pl')
r.content


r_img = requests.get('https://upload.wikimedia.org/wikipedia/commons/7/7e/Accueil_scribe_invert_300.jpg')

# %%
r_img.headers['content-type']
r_img.content
with open(file='tmp.jpg', mode='wb') as f:
    f.write(r_img.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 r_img.headers['content-type']
#       2 r_img.content
#       3 with open(file='tmp.jpg', mode='wb') as f:
#
# NameError: name 'r_img' is not defined

# %%
with open(file='tmp.jpg', mode='rb') as f:
    img_c = f.read()

# ac3 = AI_Client_Call_Wrapper.make_from_key(api_key=env["OPENAI_API_KEY"])

img_c

image_data = base64.b64encode(img_c).decode('utf-8')

image_data
# Out:
# '...'

# %%
idd = ac3.get_file_data('tmp.jpg')

idd
# Out:
# (<_io.TextIOWrapper name='tmp.jpg' mode='r' encoding='UTF-8'>,
#  'local file tmp.jpg')

# %%
rit, iit = ac3.call_image_text(img_bytes=image_data, img_name='tmp.jpg')
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rit, iit = ac3.call_image_text(img_bytes=image_data, img_name='tmp.jpg')
#
# File ~/Pulpit/zero_ai/heavy_photos/ai_client_wrapper.py:147, in AI_Client_Call_Wrapper.call_image_text(self, img_bytes, img_name)
#     145 def call_image_text(self, img_bytes:BytesIO, img_name:str=None):
# --> 147     response = self.ai_client.chat.completions.create(model=self.configs['image_text']['model'],
#     148                                                   messages=[
#     149     {"role": "system", "content": "Describe the image in detail."},
#     150     {"role": "user", "content": [{"type": "image", "image": img_bytes}]}
#     151                                                             ],
#     152                                                     max_tokens=150)
# ...
